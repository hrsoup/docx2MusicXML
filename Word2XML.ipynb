# %%
import docx
from music21 import*

file = docx.Document('Word/南派/姑苏行.docx')


#从word文件中读取乐谱相关信息
#-------------------------------------------------------------------#
#（1）乐谱题目
score_name = file.paragraphs[0].text
#（2）该曲子有几段（以转调或者转拍为分割点）
#如小放牛有两段
#乐曲中的第i段属于docx文件中的第（4+2i）段
chapter_number = int ((len(file.paragraphs) - 1) / 2)
#-------------------------------------------------------------------#


#创建socre对象，添加乐谱元信息
#-------------------------------------------------------------------#
#（1）创建一个乐谱对象
score = stream.Score()
#（2）添加声部
part = stream.Part()
part.partName = 'Di'
#（3）添加题目元信息
score.insert(0, metadata.Metadata())
score.metadata.title = score_name
#-------------------------------------------------------------------#

dur = ['z','x','c','a']
low = ['*','v','b','n']
high = ['8','*'] #应该没有倍低音，没有加倍低音
Note = ['0','1','2','3','4','5','6','7','q','w','r','T','y']

key_list = ['C','G','D','A','E','B','F#','C#','F','Bb','Eb','Ab','Db','Gb','Cb']
p = ['C','C#','D','D#','E','F','F#','G','G#','A','A#','B']
pitch_list = []

for i in range(6):
    for j in range(12):
        st = p[j] + str(i+1)
        pitch_list.append(st)


def transform_pitch(ch,k,high_low):
    temp = k + str(high_low)
    pitc = 0
    do_index = pitch_list.index(temp)
    if ch == '1':
        pitc = temp
    elif ch == 'q':
        pitc = pitch_list[do_index+1]        
    elif ch == '2':
        pitc = pitch_list[do_index+2]
    elif ch == 'w':
        pitc = pitch_list[do_index+3]
    elif ch == '3':
        pitc = pitch_list[do_index+4]
    elif ch =='4':
        pitc = pitch_list[do_index+5]
    elif ch == 'r':
        pitc = pitch_list[do_index+6]
    elif ch == '5':
        pitc = pitch_list[do_index+7]
    elif ch == 'T':
        pitc = pitch_list[do_index+8]
    elif ch == '6':
        pitc = pitch_list[do_index+9]
    elif ch == 'y':
        pitc = pitch_list[do_index+10]
    elif ch == '7':
        pitc = pitch_list[do_index+11]
    return pitc


def transform_note(l,stream,k):
    print(l)
    if l[0] == '8':
        if len(l) == 2:
            n = note.Note(transform_pitch(l[1],k,5), quarterLength=1)
        elif len(l) == 3:
            if l[2] == ':':   
                n = note.Note(transform_pitch(l[1],k,5), quarterLength=2)
            elif l[2] == "'":
                n = note.Note(transform_pitch(l[1],k,5), quarterLength=1.5)
        elif len(l) == 4:
            n = note.Note(transform_pitch(l[1],k,5), quarterLength=3)
        elif len(l) == 5:
            n = note.Note(transform_pitch(l[1],k,5), quarterLength=4)      

            
    if (l[0] in Note) == True :
        if len(l) == 1:
            if l[0] == '0':
                n = note.Rest(quarterLength=1)
            else:        
                n = note.Note(transform_pitch(l[0],k,4), quarterLength=1)
        elif len(l) == 2:
            if l[1] == ':':  
                if l[0] == '0':
                    n = note.Rest(quarterLength=2)
                else:   
                    n = note.Note(transform_pitch(l[0],k,4), quarterLength=2)
            elif l[1] == "'":
                if l[0] == '0':
                    n = note.Rest(quarterLength=1.5)
                else: 
                    n = note.Note(transform_pitch(l[0],k,4), quarterLength=1.5)
        elif len(l) == 3:
            if l[0] == '0':
                n = note.Rest(quarterLength=3)
            else: 
                n = note.Note(transform_pitch(l[0],k,4), quarterLength=3)
        elif len(l) == 4:
            if l[0] == '0':
                n = note.Rest(quarterLength=4)
            else: 
                n = note.Note(transform_pitch(l[0],k,4), quarterLength=4)
            
            
    elif (l[0] in dur) == True:
        if l[1] == '8':
            if l[0] == 'z':
                if len(l) == 3:
                    n = note.Note(transform_pitch(l[2],k,5), quarterLength=0.5)
                else:
                    n = note.Note(transform_pitch(l[2],k,5), quarterLength=0.75)                 
            elif l[0] == 'x':
                if len(l) == 3:
                    n = note.Note(transform_pitch(l[2],k,5), quarterLength=0.25)
                else:
                    if l[2] == 't' or l[2] == 's':
                        n = note.Note(transform_pitch(l[3],k,5), quarterLength=1/6)
                    elif l[2] == 'f':
                        n = note.Note(transform_pitch(l[3],k,5), quarterLength=1/5)
                    #附点
                    else:
                        n = note.Note(transform_pitch(l[2],k,5), quarterLength=0.375)               
            elif l[0] == 'c':
                if len(l) == 3:
                    n = note.Note(transform_pitch(l[2],k,5), quarterLength=0.125)
                else:
                    #附点
                    n = note.Note(transform_pitch(l[2],k,5), quarterLength=0.1875)
            elif l[0] == 'a':
                if len(l) == 3:
                    n = note.Note(transform_pitch(l[2],k,5), quarterLength=0.0625)
                else:
                    #附点
                    n = note.Note(transform_pitch(l[2],k,5), quarterLength=0.09375)
                    
        elif l[1] == '9':
            if l[0] == 'z':
                if len(l) == 3:
                    n = note.Note(transform_pitch(l[2],k,6), quarterLength=0.5)
                else:
                    n = note.Note(transform_pitch(l[2],k,6), quarterLength=0.75)                 
            elif l[0] == 'x':
                if len(l) == 3:
                    n = note.Note(transform_pitch(l[2],k,6), quarterLength=0.25)
                else:
                    if l[2] == 't' or l[2] == 's':
                        n = note.Note(transform_pitch(l[3],k,6), quarterLength=1/6)
                    elif l[2] == 'f':
                        n = note.Note(transform_pitch(l[3],k,6), quarterLength=1/5)
                    #附点
                    else:
                        n = note.Note(transform_pitch(l[2],k,6), quarterLength=0.375)               
            elif l[0] == 'c':
                if len(l) == 3:
                    n = note.Note(transform_pitch(l[2],k,6), quarterLength=0.125)
                else:
                    #附点
                    n = note.Note(transform_pitch(l[2],k,6), quarterLength=0.1875)
            elif l[0] == 'a':
                if len(l) == 3:
                    n = note.Note(transform_pitch(l[2],k,6), quarterLength=0.0625)
                else:
                    #附点
                    n = note.Note(transform_pitch(l[2],k,6), quarterLength=0.09375)
                            
        else:
            if l[0] == 'z':
                if len(l) == 2:
                    if l[1] == 't' or l[1] == 's':
                        n = note.Note(transform_pitch(l[2],k,4), quarterLength=1/3)
                    if l[1] == '0':
                        n = note.Rest(quarterLength=0.5)
                    else:
                        n = note.Note(transform_pitch(l[1],k,4), quarterLength=0.5)
                else:
                    #附点
                    if l[1] == '0':
                        n = note.Rest(quarterLength=0.75)
                    else:
                        n = note.Note(transform_pitch(l[1],k,4), quarterLength=0.75)                  
            elif l[0] == 'x':
                if len(l) == 2:
                    if l[1] == '0':
                        n = note.Rest(quarterLength=0.25)
                    else:
                        n = note.Note(transform_pitch(l[1],k,4), quarterLength=0.25)
                else:
                    if l[1] == 't' or l[1] == 's':
                        n = note.Note(transform_pitch(l[2],k,4), quarterLength=1/6)
                    elif l[1] == 'f':
                        n = note.Note(transform_pitch(l[2],k,4), quarterLength=1/5)
                    #附点
                    elif l[1] == '0':
                        n = note.Rest(quarterLength=0.375)
                    else:
                        n = note.Note(transform_pitch(l[1],k,4), quarterLength=0.375)                
            elif l[0] == 'c':
                if len(l) == 2:
                    if l[1] == '0':
                        n = note.Rest(quarterLength=0.125)
                    else:
                        n = note.Note(transform_pitch(l[1],k,4), quarterLength=0.125)
                else:
                    #附点
                    if l[1] == 't' or l[1] == 's':
                        n = note.Note(transform_pitch(l[2],k,4), quarterLength=1/12)
                    elif l[0] == '0':
                        n = note.Rest(quarterLength=0.1875)
                    else:
                        n = note.Note(transform_pitch(l[1],k,4), quarterLength=0.1875) 
            elif l[0] == 'a':
                if len(l) == 2:
                    if l[1] == '0':
                        n = note.Rest(quarterLength=0.0625)
                    else:
                        n = note.Note(transform_pitch(l[1],k,4), quarterLength=0.0625)
                else:
                    #附点
                    if l[0] == '0':
                        n = note.Rest(quarterLength=0.09375)
                    else:
                        n = note.Note(transform_pitch(l[1],k,4), quarterLength=0.09375)


    elif (l[0] in low) == True:
        if l[0] == '*':
            if len(l) == 2:
                n = note.Note(transform_pitch(l[1],k,3), quarterLength=1)
            elif len(l) == 3:
                if l[2] == ':':
                    n = note.Note(transform_pitch(l[1],k,3), quarterLength=2)
                elif l[2] == "'":
                    ##附点
                    n = note.Note(transform_pitch(l[1],k,3), quarterLength=1.5)
            elif len(l) == 4:
                n = note.Note(transform_pitch(l[1],k,3), quarterLength=3)
            elif len(l) == 5:
                n = note.Note(transform_pitch(l[1],k,3), quarterLength=4)
        elif l[0] == 'v':
            if len(l) == 2:
                n = note.Note(transform_pitch(l[1],k,3), quarterLength=0.5) 
            else:
                if l[1] == 't' or l[1] == 't':
                    n = note.Note(transform_pitch(l[2],k,3), quarterLength=1/3)
                elif l[1] == 'f':
                    n = note.Note(transform_pitch(l[2],k,3), quarterLength=2/5)
                ##加附点
                else:
                    n = note.Note(transform_pitch(l[1],k,3), quarterLength=0.75)
        elif l[0] == 'b':
            if len(l) == 2:
                n = note.Note(transform_pitch(l[1],k,3), quarterLength=0.25)  
            else:
                if l[1] == 't' or l[1] == 't':
                    n = note.Note(transform_pitch(l[2],k,3), quarterLength=1/6)
                ##加附点
                elif l[1] == 'f':
                    n = note.Note(transform_pitch(l[2],k,3), quarterLength=1/5)
                else:
                    n = note.Note(transform_pitch(l[1],k,3), quarterLength=0.375)
        elif l[0] == 'n':
                n = note.Note(transform_pitch(l[1],k,3), quarterLength=0.125)
    stream1.append(n)
    return stream1


def ifend(section, count):
    if count == len(section) - 1:
        return True
    elif (section[count] in Note) == True:
        if (count + 2) <= (len(section) - 1):
            if section[count+1] != ':' and section[count+1] != "'" and section[count+2] != ';':
                return True
            else:
                return False
        elif (count + 1) <= (len(section) - 1):
            if section[count+1] != ':' and section[count+1] != "'":
                return True
            else: 
                return False
        else:
            return False
    elif section[count] == "'" or section[count] == ";":
        return True
    elif (section[count] == ":") and (section[count+1] != ":"):
        return True
    else:
        return False

def cal_techique(l,k,meter):
    tec = []
    no = []
    mu = 0
    tech = 0
    for ch in l:
        if (ch == '|') and (mu == 0):
            mu = 1
        elif (ch == '|') and (mu == 1):
            mu = 0
        elif mu == 1:
            tec.append(ch)
        elif mu == 0:
            no.append(ch)
    tec = ''.join(tec)
    no = ''.join(no)
    

    if tech == 0:
        sta = '0'
    else:
        sta = tec
    return no,sta

#（3）处理含音符段的信息
#-------------------------------------------------------------------#
#将word中的字符转换成musicxml中的stream
def text_process(text, stream1,k):
    text = text.replace(" ","")
    section_list = text.split('/')
    #每个section为一个小节，现在对每一个小节进行处理              
    for section in section_list:
        count = 0
        mutex = 0
        current_note = []
        for character in section:              
            if (character == '|') and (mutex == 0): #mutex为1时是技巧
                mutex = 1
                current_note.append(character)
            elif (character == '|') and (mutex == 1):
                mutex = 0
                current_note.append(character)
            elif (ifend(section,count) == True) and (mutex == 0):
                current_note.append(character)
                current_note = ''.join(current_note)
                print(count,section)
                x,y = cal_techique(current_note,k,meter)
                stream1 = transform_note(x,stream1,k)
                current_note = []
            else:
                current_note.append(character)
            count += 1
            #如果已经是该小节最后一个字符，也结束
            if count == len(section):
                current_note = ''.join(current_note)
                
    return stream1


for i in range(chapter_number):
    stream1 = stream.Stream()
    l = file.paragraphs[1+2*i].text.split(' ')
    k = l[0][2:3]
    #加调号
    index = int(key_list.index(k))
    #加拍号
    stream1.append(key.KeySignature(index))
    stream1.append(meter.TimeSignature(l[1]))
    stream1 = text_process(file.paragraphs[2+2*i].text,stream1,k)
    part.append(stream1)
#-------------------------------------------------------------------#
    
    
#（4）将声部添加到乐谱中
score.insert(0, part)
#（5）将乐谱以xml格式保存
score.write('xml',fp=str(score_name)+'.xml')
# Out:
# 6 |Y82|81z|D|81z|d|82z|d|6z81|d|5
# 81
# 12 |Y82|81z|D|81z|d|82z|d|6z81|d|5
# z81
# 32 z|Y7|6z;x|t|6|y4q|5z1v|D|6z|d|2z4
# z4
# 4 |B|3:z|D|3z|t|3|y4q|2
# 3:
# 9 |B|3:z|D|3z|t|3|y4q|2
# z3
# 14 |B|3:z|D|3z|t|3|y4q|2
# z3
# 20 |B|3:z|D|3z|t|3|y4q|2
# 2
# 3 |B|3z|Y817|6z|d|81z5z|d|6z|d|3z5
# 3
# 11 |B|3z|Y817|6z|d|81z5z|d|6z|d|3z5
# z6
# 17 |B|3z|Y817|6z|d|81z5z|d|6z|d|3z5
# z81
# 19 |B|3z|Y817|6z|d|81z5z|d|6z|d|3z5
# z5
# 24 |B|3z|Y817|6z|d|81z5z|d|6z|d|3z5
# z6
# 29 |B|3z|Y817|6z|d|81z5z|d|6z|d|3z5
# z3
# 31 |B|3z|Y817|6z|d|81z5z|d|6z|d|3z5
# z5
# 5 |Y3|2:z|D|2z|t|2|y4q|1
# 2:
# 10 |Y3|2:z|D|2z|t|2|y4q|1
# z2
# 15 |Y3|2:z|D|2z|t|2|y4q|1
# z2
# 21 |Y3|2:z|D|2z|t|2|y4q|1
# 1
# 4 |Y3|25|B|3v|Y*7|6v|y4q|5
# 2
# 5 |Y3|25|B|3v|Y*7|6v|y4q|5
# 5
# 9 |Y3|25|B|3v|Y*7|6v|y4q|5
# 3
# 16 |Y3|25|B|3v|Y*7|6v|y4q|5
# v6
# 23 |Y3|25|B|3v|Y*7|6v|y4q|5
# v5
# 6 |Y2|1::z|d|2z|dy4q|3
# 1::
# 11 |Y2|1::z|d|2z|dy4q|3
# z2
# 19 |Y2|1::z|d|2z|dy4q|3
# z3
# 1 x5x|d|6x3x2x5x3x5x|d|6
# x5
# 6 x5x|d|6x3x2x5x3x5x|d|6
# x6
# 8 x5x|d|6x3x2x5x3x5x|d|6
# x3
# 10 x5x|d|6x3x2x5x3x5x|d|6
# x2
# 12 x5x|d|6x3x2x5x3x5x|d|6
# x5
# 14 x5x|d|6x3x2x5x3x5x|d|6
# x3
# 16 x5x|d|6x3x2x5x3x5x|d|6
# x5
# 21 x5x|d|6x3x2x5x3x5x|d|6
# x6
# 2 x81x6x81x|d|83x82x|d|83z|q|81
# x81
# 4 x81x6x81x|d|83x82x|d|83z|q|81
# x6
# 7 x81x6x81x|d|83x82x|d|83z|q|81
# x81
# 13 x81x6x81x|d|83x82x|d|83z|q|81
# x83
# 16 x81x6x81x|d|83x82x|d|83z|q|81
# x82
# 22 x81x6x81x|d|83x82x|d|83z|q|81
# x83
# 28 x81x6x81x|d|83x82x|d|83z|q|81
# z81
# 1 z0z|T|83x82x|d|83x82x81
# z0
# 7 z0z|T|83x82x|d|83x82x81
# z83
# 10 z0z|T|83x82x|d|83x82x81
# x82
# 16 z0z|T|83x82x|d|83x82x81
# x83
# 19 z0z|T|83x82x|d|83x82x81
# x82
# 22 z0z|T|83x82x|d|83x82x81
# x81
# 4 x|d|6x81x82x|d|83x81x|d|82x81x|d|6
# x6
# 7 x|d|6x81x82x|d|83x81x|d|82x81x|d|6
# x81
# 10 x|d|6x81x82x|d|83x81x|d|82x81x|d|6
# x82
# 16 x|d|6x81x82x|d|83x81x|d|82x81x|d|6
# x83
# 19 x|d|6x81x82x|d|83x81x|d|82x81x|d|6
# x81
# 25 x|d|6x81x82x|d|83x81x|d|82x81x|d|6
# x82
# 28 x|d|6x81x82x|d|83x81x|d|82x81x|d|6
# x81
# 33 x|d|6x81x82x|d|83x81x|d|82x81x|d|6
# x6
# 1 x5x6x81x|d|82x6x81x|d|6x5
# x5
# 3 x5x6x81x|d|82x6x81x|d|6x5
# x6
# 6 x5x6x81x|d|82x6x81x|d|6x5
# x81
# 12 x5x6x81x|d|82x6x81x|d|6x5
# x82
# 14 x5x6x81x|d|82x6x81x|d|6x5
# x6
# 17 x5x6x81x|d|82x6x81x|d|6x5
# x81
# 22 x5x6x81x|d|82x6x81x|d|6x5
# x6
# 24 x5x6x81x|d|82x6x81x|d|6x5
# x5
# 1 x3x5x|d|6x81x5x|d|6x5x2
# x3
# 3 x3x5x|d|6x81x5x|d|6x5x2
# x5
# 8 x3x5x|d|6x81x5x|d|6x5x2
# x6
# 11 x3x5x|d|6x81x5x|d|6x5x2
# x81
# 13 x3x5x|d|6x81x5x|d|6x5x2
# x5
# 18 x3x5x|d|6x81x5x|d|6x5x2
# x6
# 20 x3x5x|d|6x81x5x|d|6x5x2
# x5
# 22 x3x5x|d|6x81x5x|d|6x5x2
# x2
# 1 x2x5x3x|B|2x2b6z|y4q|1
# x2
# 3 x2x5x3x|B|2x2b6z|y4q|1
# x5
# 5 x2x5x3x|B|2x2b6z|y4q|1
# x3
# 10 x2x5x3x|B|2x2b6z|y4q|1
# x2
# 12 x2x5x3x|B|2x2b6z|y4q|1
# x2
# 14 x2x5x3x|B|2x2b6z|y4q|1
# b6
# 21 x2x5x3x|B|2x2b6z|y4q|1
# z1
# 1 z0z|B|3x2x1z|y4dq|2
# z0
# 6 z0z|B|3x2x1z|y4dq|2
# z3
# 8 z0z|B|3x2x1z|y4dq|2
# x2
# 10 z0z|B|3x2x1z|y4dq|2
# x1
# 18 z0z|B|3x2x1z|y4dq|2
# z2
# 1 z0x2x3x5x3z|y1q|5
# z0
# 3 z0x2x3x5x3z|y1q|5
# x2
# 5 z0x2x3x5x3z|y1q|5
# x3
# 7 z0x2x3x5x3z|y1q|5
# x5
# 9 z0x2x3x5x3z|y1q|5
# x3
# 16 z0x2x3x5x3z|y1q|5
# z5
# 1 z0x5x|d|6x81x6x81x|d|83
# z0
# 3 z0x5x|d|6x81x6x81x|d|83
# x5
# 8 z0x5x|d|6x81x6x81x|d|83
# x6
# 11 z0x5x|d|6x81x6x81x|d|83
# x81
# 13 z0x5x|d|6x81x6x81x|d|83
# x6
# 16 z0x5x|d|6x81x6x81x|d|83
# x81
# 22 z0x5x|d|6x81x6x81x|d|83
# x83
# 2 x82x|d|83x82x81x|d|6x81x82x|d|83
# x82
# 8 x82x|d|83x82x81x|d|6x81x82x|d|83
# x83
# 11 x82x|d|83x82x81x|d|6x81x82x|d|83
# x82
# 14 x82x|d|83x82x81x|d|6x81x82x|d|83
# x81
# 19 x82x|d|83x82x81x|d|6x81x82x|d|83
# x6
# 22 x82x|d|83x82x81x|d|6x81x82x|d|83
# x81
# 25 x82x|d|83x82x81x|d|6x81x82x|d|83
# x82
# 31 x82x|d|83x82x81x|d|6x81x82x|d|83
# x83
# 2 x81x|d|82x81x|d|6x2x6x81x|d|82
# x81
# 8 x81x|d|82x81x|d|6x2x6x81x|d|82
# x82
# 11 x81x|d|82x81x|d|6x2x6x81x|d|82
# x81
# 16 x81x|d|82x81x|d|6x2x6x81x|d|82
# x6
# 18 x81x|d|82x81x|d|6x2x6x81x|d|82
# x2
# 20 x81x|d|82x81x|d|6x2x6x81x|d|82
# x6
# 23 x81x|d|82x81x|d|6x2x6x81x|d|82
# x81
# 29 x81x|d|82x81x|d|6x2x6x81x|d|82
# x82
# 1 x6x81x|d|6x5x3x5x|d|6x81
# x6
# 4 x6x81x|d|6x5x3x5x|d|6x81
# x81
# 9 x6x81x|d|6x5x3x5x|d|6x81
# x6
# 11 x6x81x|d|6x5x3x5x|d|6x81
# x5
# 13 x6x81x|d|6x5x3x5x|d|6x81
# x3
# 15 x6x81x|d|6x5x3x5x|d|6x81
# x5
# 20 x6x81x|d|6x5x3x5x|d|6x81
# x6
# 23 x6x81x|d|6x5x3x5x|d|6x81
# x81
# 3 z5z;x|d|6x5x|d|6x5x|B|3
# z5z;
# 8 z5z;x|d|6x5x|d|6x5x|B|3
# x6
# 10 z5z;x|d|6x5x|d|6x5x|B|3
# x5
# 15 z5z;x|d|6x5x|d|6x5x|B|3
# x6
# 17 z5z;x|d|6x5x|d|6x5x|B|3
# x5
# 22 z5z;x|d|6x5x|d|6x5x|B|3
# x3
# 1 z2x|D|2x3x5x81x|d|6x5
# z2
# 6 z2x|D|2x3x5x81x|d|6x5
# x2
# 8 z2x|D|2x3x5x81x|d|6x5
# x3
# 10 z2x|D|2x3x5x81x|d|6x5
# x5
# 13 z2x|D|2x3x5x81x|d|6x5
# x81
# 18 z2x|D|2x3x5x81x|d|6x5
# x6
# 20 z2x|D|2x3x5x81x|d|6x5
# x5
# 1 z4c|d|6c5c3c2x3x2z1
# z4
# 6 z4c|d|6c5c3c2x3x2z1
# c6
# 8 z4c|d|6c5c3c2x3x2z1
# c5
# 10 z4c|d|6c5c3c2x3x2z1
# c3
# 12 z4c|d|6c5c3c2x3x2z1
# c2
# 14 z4c|d|6c5c3c2x3x2z1
# x3
# 16 z4c|d|6c5c3c2x3x2z1
# x2
# 18 z4c|d|6c5c3c2x3x2z1
# z1
# 1 x2x|d|3x2x1b6x1z|dy4q|2
# x2
# 6 x2x|d|3x2x1b6x1z|dy4q|2
# x3
# 8 x2x|d|3x2x1b6x1z|dy4q|2
# x2
# 10 x2x|d|3x2x1b6x1z|dy4q|2
# x1
# 12 x2x|d|3x2x1b6x1z|dy4q|2
# b6
# 14 x2x|d|3x2x1b6x1z|dy4q|2
# x1
# 22 x2x|d|3x2x1b6x1z|dy4q|2
# z2
# 3 z0z;x|t|6z5z;x|d|6
# z0z;
# 8 z0z;x|t|6z5z;x|d|6
# x6
# 12 z0z;x|t|6z5z;x|d|6
# z5z;
# 17 z0z;x|t|6z5z;x|d|6
# x6
# 3 z4z;x5z|d|6z;x|B|7
# z4z;
# 5 z4z;x5z|d|6z;x|B|7
# x5
# 12 z4z;x5z|d|6z;x|B|7
# z6z;
# 17 z4z;x5z|d|6z;x|B|7
# x7
# 3 z6z;x|B|5z4z;x|B|5
# z6z;
# 8 z6z;x|B|5z4z;x|B|5
# x5
# 12 z6z;x|B|5z4z;x|B|5
# z4z;
# 17 z6z;x|B|5z4z;x|B|5
# x5
# 4 z|T|3z|B|3x2x|d|3x2x1
# z3
# 9 z|T|3z|B|3x2x|d|3x2x1
# z3
# 11 z|T|3z|B|3x2x|d|3x2x1
# x2
# 16 z|T|3z|B|3x2x|d|3x2x1
# x3
# 18 z|T|3z|B|3x2x|d|3x2x1
# x2
# 20 z|T|3z|B|3x2x|d|3x2x1
# x1
# 4 v|d|6b|D|6x1x|d|2x1z|dy4q|2
# v6
# 9 v|d|6b|D|6x1x|d|2x1z|dy4q|2
# b6
# 11 v|d|6b|D|6x1x|d|2x1z|dy4q|2
# x1
# 16 v|d|6b|D|6x1x|d|2x1z|dy4q|2
# x2
# 18 v|d|6b|D|6x1x|d|2x1z|dy4q|2
# x1
# 26 v|d|6b|D|6x1x|d|2x1z|dy4q|2
# z2
# 1 z0z1z|d|3z|t|6
# z0
# 3 z0z1z|d|3z|t|6
# z1
# 8 z0z1z|d|3z|t|6
# z3
# 13 z0z1z|d|3z|t|6
# z6
# 1 x5x|d|6x5x3x2x1z|dy4q|2
# x5
# 6 x5x|d|6x5x3x2x1z|dy4q|2
# x6
# 8 x5x|d|6x5x3x2x1z|dy4q|2
# x5
# 10 x5x|d|6x5x3x2x1z|dy4q|2
# x3
# 12 x5x|d|6x5x3x2x1z|dy4q|2
# x2
# 14 x5x|d|6x5x3x2x1z|dy4q|2
# x1
# 22 x5x|d|6x5x3x2x1z|dy4q|2
# z2
# 1 z0z1x|d|2x3x5x|d|6
# z0
# 3 z0z1x|d|2x3x5x|d|6
# z1
# 8 z0z1x|d|2x3x5x|d|6
# x2
# 10 z0z1x|d|2x3x5x|d|6
# x3
# 12 z0z1x|d|2x3x5x|d|6
# x5
# 17 z0z1x|d|2x3x5x|d|6
# x6
# 1 x3x5x3x|B|2z1z|Dy4q|1
# x3
# 3 x3x5x3x|B|2z1z|Dy4q|1
# x5
# 5 x3x5x3x|B|2z1z|Dy4q|1
# x3
# 10 x3x5x3x|B|2z1z|Dy4q|1
# x2
# 12 x3x5x3x|B|2z1z|Dy4q|1
# z1
# 20 x3x5x3x|B|2z1z|Dy4q|1
# z1
# 1 z0x81x82x83x85x83x|B|82
# z0
# 4 z0x81x82x83x85x83x|B|82
# x81
# 7 z0x81x82x83x85x83x|B|82
# x82
# 10 z0x81x82x83x85x83x|B|82
# x83
# 13 z0x81x82x83x85x83x|B|82
# x85
# 16 z0x81x82x83x85x83x|B|82
# x83
# 22 z0x81x82x83x85x83x|B|82
# x82
# 2 x81x82x83x85x82x|d|83x82x81
# x81
# 5 x81x82x83x85x82x|d|83x82x81
# x82
# 8 x81x82x83x85x82x|d|83x82x81
# x83
# 11 x81x82x83x85x82x|d|83x82x81
# x85
# 14 x81x82x83x85x82x|d|83x82x81
# x82
# 20 x81x82x83x85x82x|d|83x82x81
# x83
# 23 x81x82x83x85x82x|d|83x82x81
# x82
# 26 x81x82x83x85x82x|d|83x82x81
# x81
# 4 x|d|6x81x82x|d|83x81x|d|82x81x|d|6
# x6
# 7 x|d|6x81x82x|d|83x81x|d|82x81x|d|6
# x81
# 10 x|d|6x81x82x|d|83x81x|d|82x81x|d|6
# x82
# 16 x|d|6x81x82x|d|83x81x|d|82x81x|d|6
# x83
# 19 x|d|6x81x82x|d|83x81x|d|82x81x|d|6
# x81
# 25 x|d|6x81x82x|d|83x81x|d|82x81x|d|6
# x82
# 28 x|d|6x81x82x|d|83x81x|d|82x81x|d|6
# x81
# 33 x|d|6x81x82x|d|83x81x|d|82x81x|d|6
# x6
# 1 x5x6x81x|d|82x6x81x|d|6x5
# x5
# 3 x5x6x81x|d|82x6x81x|d|6x5
# x6
# 6 x5x6x81x|d|82x6x81x|d|6x5
# x81
# 12 x5x6x81x|d|82x6x81x|d|6x5
# x82
# 14 x5x6x81x|d|82x6x81x|d|6x5
# x6
# 17 x5x6x81x|d|82x6x81x|d|6x5
# x81
# 22 x5x6x81x|d|82x6x81x|d|6x5
# x6
# 24 x5x6x81x|d|82x6x81x|d|6x5
# x5
# 1 x3x5x6x81x|d|6x5x3x2
# x3
# 3 x3x5x6x81x|d|6x5x3x2
# x5
# 5 x3x5x6x81x|d|6x5x3x2
# x6
# 8 x3x5x6x81x|d|6x5x3x2
# x81
# 13 x3x5x6x81x|d|6x5x3x2
# x6
# 15 x3x5x6x81x|d|6x5x3x2
# x5
# 17 x3x5x6x81x|d|6x5x3x2
# x3
# 19 x3x5x6x81x|d|6x5x3x2
# x2
# 5 z|Tq|1z|B|3x2x3x2x1
# z1
# 10 z|Tq|1z|B|3x2x3x2x1
# z3
# 12 z|Tq|1z|B|3x2x3x2x1
# x2
# 14 z|Tq|1z|B|3x2x3x2x1
# x3
# 16 z|Tq|1z|B|3x2x3x2x1
# x2
# 18 z|Tq|1z|B|3x2x3x2x1
# x1
# 5 v|Tq|6z|t|2x1x|d|2b|d|6b5
# v6
# 10 v|Tq|6z|t|2x1x|d|2b|d|6b5
# z2
# 12 v|Tq|6z|t|2x1x|d|2b|d|6b5
# x1
# 17 v|Tq|6z|t|2x1x|d|2b|d|6b5
# x2
# 22 v|Tq|6z|t|2x1x|d|2b|d|6b5
# b6
# 24 v|Tq|6z|t|2x1x|d|2b|d|6b5
# b5
# 4 z|d|1x|D|1x2z|d|3z|q|5
# z1
# 9 z|d|1x|D|1x2z|d|3z|q|5
# x1
# 11 z|d|1x|D|1x2z|d|3z|q|5
# x2
# 16 z|d|1x|D|1x2z|d|3z|q|5
# z3
# 21 z|d|1x|D|1x2z|d|3z|q|5
# z5
# 4 z|d|1v|d|6z|d|1z|Y3X|2
# z1
# 9 z|d|1v|d|6z|d|1z|Y3X|2
# v6
# 14 z|d|1v|d|6z|d|1z|Y3X|2
# z1
# 21 z|d|1v|d|6z|d|1z|Y3X|2
# z2
# 5 |Y6X|5|D|5:|By4q|3
# 5
# 10 |Y6X|5|D|5:|By4q|3
# 5:
# 17 |Y6X|5|D|5:|By4q|3
# 3
# 6 |Y82|81|D|81z|D|81z|d|82z|d|83z|t|82
# 81
# 11 |Y82|81|D|81z|D|81z|d|82z|d|83z|t|82
# 81
# 17 |Y82|81|D|81z|D|81z|d|82z|d|83z|t|82
# z81
# 23 |Y82|81|D|81z|D|81z|d|82z|d|83z|t|82
# z82
# 29 |Y82|81|D|81z|D|81z|d|82z|d|83z|t|82
# z83
# 35 |Y82|81|D|81z|D|81z|d|82z|d|83z|t|82
# z82
# 1 81|D|81|D|81|dy82|6
# 81
# 6 81|D|81|D|81|dy82|6
# 81
# 11 81|D|81|D|81|dy82|6
# 81
# 18 81|D|81|D|81|dy82|6
# 6
# 6 z|Y5|82z|t|83z81z|D|81z|t|3z2z5z|t|7
# z82
# 12 z|Y5|82z|t|83z81z|D|81z|t|3z2z5z|t|7
# z83
# 15 z|Y5|82z|t|83z81z|D|81z|t|3z2z5z|t|7
# z81
# 21 z|Y5|82z|t|83z81z|D|81z|t|3z2z5z|t|7
# z81
# 26 z|Y5|82z|t|83z81z|D|81z|t|3z2z5z|t|7
# z3
# 28 z|Y5|82z|t|83z81z|D|81z|t|3z2z5z|t|7
# z2
# 30 z|Y5|82z|t|83z81z|D|81z|t|3z2z5z|t|7
#